# %%
print(~2)
print(~2)

decimal_num = 10
# Using format()
binary_str_format = format(decimal_num, 'b')
print(binary_str_format) # Output: 1010
# Out:
# -3
# -3
# 1010

# %%
print('NNNN')
# Out:
# NNNN
